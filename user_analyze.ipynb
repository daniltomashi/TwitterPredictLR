# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
users = pd.read_csv('datasets/users.csv')

# %%
users
# Out:
#              id      screen_name  followers_count                 created_at  \
# 0      98714923       MzVenomous                2  2009-12-22 20:38:48+00:00
# 1      74157087          amaraux                0  2009-09-14 13:34:40+00:00
# 2      67495384   loverenanthuco               13  2009-08-21 02:15:46+00:00
# 3      64221267        Gugel1983                9  2009-08-09 18:15:26+00:00
# 4      85158771   Sarah_Bourbeau               22  2009-10-25 20:34:53+00:00
# ...         ...              ...              ...                        ...
# 46153  33017170        BigBallas                2  2009-04-18 21:24:02+00:00
# 46154  29887925     bigboyinbama                2  2009-04-09 01:49:41+00:00
# 46155  83181650  PC_PS3_GameTips               43  2009-10-17 17:43:06+00:00
# 46156  45523007      RainaVerina              561  2009-06-08 07:56:56+00:00
# 46157  42978195    TerryMartin81                2  2009-05-27 22:04:35+00:00
#
# ...

# %%
users.describe()
# Out:
#                  id  followers_count  statuses_count  friends_count
# count  4.615800e+04     4.615800e+04    4.615800e+04   46158.000000
# mean   5.669867e+07     1.268532e+03    1.688221e+03     146.589562
# std    2.533986e+07     1.854692e+05    1.168820e+04     712.110746
# min    5.297000e+03     0.000000e+00    0.000000e+00       0.000000
# 25%    3.508169e+07     1.000000e+00    0.000000e+00       0.000000
# 50%    5.661129e+07     4.000000e+00    4.000000e+00       9.000000
# 75%    7.872927e+07     2.800000e+01    1.000000e+02      68.000000
# max    9.999928e+07     3.961730e+07    1.295410e+06   45682.000000

# %%
users[users['followers_count'] == 0].describe()
# Out:
#                  id  followers_count  statuses_count  friends_count
# count  8.733000e+03           8733.0     8733.000000    8733.000000
# mean   6.798583e+07              0.0       24.359556       6.062636
# std    2.440234e+07              0.0      654.323010      64.603589
# min    8.149060e+05              0.0        0.000000       0.000000
# 25%    5.514885e+07              0.0        0.000000       0.000000
# 50%    7.374255e+07              0.0        0.000000       0.000000
# 75%    8.781907e+07              0.0        1.000000       2.000000
# max    9.999816e+07              0.0    44444.000000    5000.000000

# %%
users = users.drop(users[users['protected'] == True].index, axis=0)

# %%
users[users['followers_count'] == 0].sort_values('statuses_count', ascending=False)
# Out:
#              id    screen_name  followers_count                 created_at  \
# 37070  53137659       bobocaao                0  2009-07-02 18:02:38+00:00
# 19218  88270576  charlydu76690                0  2009-11-07 21:02:52+00:00
# 19713  83246922       CADinger                0  2009-10-17 23:34:08+00:00
# 18770  94806011        _Sancha                0  2009-12-05 14:57:29+00:00
# 40119  92626324       v3NoM123                0  2009-11-25 22:23:17+00:00
# ...         ...            ...              ...                        ...
# 23595  92625027        cats493                0  2009-11-25 22:16:34+00:00
# 23593  86197666         iram86                0  2009-10-30 00:04:07+00:00
# 23585  73728263   kimbubbles97                0  2009-09-12 20:34:42+00:00
# 23567  96306333       tta_tita                0  2009-12-12 08:43:41+00:00
# 27869  98387003     auliahasim                0  2009-12-21 14:10:23+00:00
#
#        protected  verified  statuses_count  friends_count
# ...

# %%
users
# Out:
#              id      screen_name  followers_count                 created_at  \
# 0      98714923       MzVenomous                2  2009-12-22 20:38:48+00:00
# 1      74157087          amaraux                0  2009-09-14 13:34:40+00:00
# 2      67495384   loverenanthuco               13  2009-08-21 02:15:46+00:00
# 3      64221267        Gugel1983                9  2009-08-09 18:15:26+00:00
# 5      35801430    Jamie_Hanbury                3  2009-04-27 17:30:19+00:00
# ...         ...              ...              ...                        ...
# 46153  33017170        BigBallas                2  2009-04-18 21:24:02+00:00
# 46154  29887925     bigboyinbama                2  2009-04-09 01:49:41+00:00
# 46155  83181650  PC_PS3_GameTips               43  2009-10-17 17:43:06+00:00
# 46156  45523007      RainaVerina              561  2009-06-08 07:56:56+00:00
# 46157  42978195    TerryMartin81                2  2009-05-27 22:04:35+00:00
#
# ...

# %%
plt.figure(figsize=(15,9))

sns.scatterplot([i for i in range(len(users[users['followers_count'] == 0]))],\
                 users[users['followers_count'] == 0].statuses_count)
# Out:
# /home/danilo/.local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='statuses_count'>

# %%
users.to_csv('datasets/users.csv', index=False)
